# %% [markdown]
# # SparkSQL Example

# %%
Create a new Spark session for this notebook first. To identify it in the Spark UI at (http://localhost:8081) correctly the application will equal the notebooks filename.

# %%
from pyspark.sql import SparkSession
import ipynbname

try:
    SparkSession.builder.master("spark://spark:7077").getOrCreate().stop()
except:
    print("Stop session failed")

try:    
    spark = SparkSession.builder \
        .appName(ipynbname.name()) \
        .master("spark://spark:7077") \
        .config("spark.sql.shuffle.partitions", "10") \
        .getOrCreate()
    print(spark)
except:
    print("Failed to create a new Spark Session" )

print("Spark session is ready! 🚀")
# Out:
# <pyspark.sql.session.SparkSession object at 0x798c7d145150>
# Spark session is ready! 🚀
# 26/01/22 11:01:34 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/01/22 11:01:34 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %% [markdown]
# # Create a namespace in the catalog
#
# Connection details for the Polaris Catalog are defined in the .pyiceberg.yaml file, which has been volumed into the spark container, so we can simply connect to the *default* catalog without specifiying connection details, credentials etc.

# %%
# %%sql
#
# CREATE SCHEMA IF NOT EXISTS landing;
# Out:
# 26/01/22 11:01:34 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS landing.testtable(
#     id  int,
#     category  varchar(20),
#     amount numeric(16,2)
# );
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT * FROM landing.testtable
# Out:
# +----+----------+--------+
# | id | category | amount |
# +----+----------+--------+
# +----+----------+--------+

# %%
try:
    SparkSession.builder.master("spark://spark:7077").getOrCreate().stop()
except:
    print("Stop session failed")
