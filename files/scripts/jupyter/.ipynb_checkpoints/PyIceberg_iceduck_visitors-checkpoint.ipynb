# %% [markdown]
# # PyIceberg - Create a namespace in MinIO/Polaris

# %%
from pyiceberg import __version__

__version__
# Out:
# '0.10.0'

# %% [markdown]
# # Create a namespace in the catalog
#
# Connection details for the Polaris Catalog are defined in the .pyiceberg.yaml file, which has been volumed into the spark container, so we can simply connect to the *default* catalog without specifiying connection details, credentials etc.

# %%
from pyiceberg.catalog import load_catalog
from pyiceberg.io.fsspec import FsspecFileIO
from pyiceberg.exceptions import NamespaceAlreadyExistsError

cat = load_catalog("default")

# show existing namespaces and tables
for ns in cat.list_namespaces():
    print(ns)
    print(cat.list_tables(ns))

try:
    cat.create_namespace("iceduck")
except NamespaceAlreadyExistsError:
    print("Namespace iceduck does already exist.")
# Out:
# ('testschema',)
# [('testschema', 'bla')]
# ('iceduck',)
# [('iceduck', 'visitors')]
# ('seeds',)
# [('seeds', 'testtable')]
# Namespace iceduck does already exist.

# %% [markdown]
# ## create a table in the new namespace

# %%
from pyiceberg.schema import Schema
from pyiceberg.types import NestedField, IntegerType, StringType, FloatType, TimestampType

schema = Schema(
    NestedField(field_id=1, name="visit_timestamp", field_type=TimestampType(), required=True),
    NestedField(field_id=2, name="visitor", field_type=StringType(), required=True),
    NestedField(field_id=3, name="description", field_type=StringType(), required=True),
)

iceberg_table = cat.create_table_if_not_exists(
    identifier='iceduck.visitors',
    schema=schema
)

print(iceberg_table.schema())
# Out:
# table {
#   1: visit_timestamp: optional timestamp
#   2: visitor: optional string
#   3: description: optional string
# }

# %% [markdown]
# ## finally, add some data

# %%
import pyarrow as pa
import datetime

pa_table_data = pa.Table.from_pylist([
    {'visit_timestamp': datetime.datetime.now().timestamp() , 'visitor': 'PyIceberg', 'description': 'created with PyIceberg in Jupyter'},
], schema=iceberg_table.schema().as_arrow())

iceberg_table.append(df=pa_table_data)
